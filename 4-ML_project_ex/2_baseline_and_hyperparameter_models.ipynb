# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn import preprocessing
from urllib.request import urlretrieve
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',150)
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(10,6)
matplotlib.rcParams['figure.facecolor']='#00000000'

# %% [markdown]
# **Reading values from Parquet**

# %%
train_inputs=pd.read_parquet('train_inputs.parquet')
val_inputs=pd.read_parquet('val_inputs.parquet')
test_inputs=pd.read_parquet('test_inputs.parquet')

X_train=pd.read_parquet('X_train.parquet')
X_val=pd.read_parquet('X_val.parquet')
X_test=pd.read_parquet('X_test.parquet')

train_targets=pd.read_parquet('train_targets.parquet')['Sales']
val_targets=pd.read_parquet('val_targets.parquet')['Sales']

# %%
print('train_inputs: ',train_inputs.shape)
print('train_targets: ',train_targets.shape)
print('X_train: ',X_train.shape)
print('val_inputs: ',val_inputs.shape)
print('val_targets: ',val_targets.shape)
print('X_val: ',X_val.shape)
print('test_inputs: ',test_inputs.shape)
print('Xtest.shape: ',X_test.shape)
# Out:
# train_inputs:  (633294, 29)
# train_targets:  (633294,)
# X_train:  (633294, 24)
# val_inputs:  (211098, 29)
# val_targets:  (211098,)
# X_val:  (211098, 24)
# test_inputs:  (41088, 29)
# Xtest.shape:  (41088, 24)

# %% [markdown]
# ***Linear Regression***

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score
def get_score(inputs,targets,model):
    pred=model.predict(inputs)
    # RMSE
    rmse = np.sqrt(mean_squared_error(targets, pred))
    print("RMSE:", rmse)

    # MAE
    mae = mean_absolute_error(targets, pred)
    print("MAE:", mae)

    # R² Score
    r2 = r2_score(targets, pred)
    print("R² Score:", r2)

    rmspe = (rmse / 6955.514291) * 100
    print("RMSPE: ",rmspe)

# %%
def try_model(model):
    model=model.fit(X_train,train_targets)
    print("for training: ")
    get_score(X_train,train_targets,model)
    print('------------------------------------------------------------------------')
    print("for validation: ")
    get_score(X_val,val_targets,model)
    return model

# %%
from sklearn.linear_model import LinearRegression
try_model(LinearRegression())
# Out:
# for training:
# RMSE: 2741.5871919165784
# MAE: 1996.5885950321917
# R² Score: 0.2083706572922308
# RMSPE:  39.41602413877606
# ------------------------------------------------------------------------
# for validation:
# RMSE: 2817.7797940117116
# MAE: 2013.775037808946
# R² Score: 0.2043437152911447
# RMSPE:  40.511451434407114
# LinearRegression()

# %% [markdown]
# ***Ridge Regression***

# %%
from sklearn.linear_model import Ridge
try_model(Ridge())
# Out:
# for training:
# RMSE: 2741.5871950814444
# MAE: 1996.5881892849784
# R² Score: 0.20837065546452993
# RMSPE:  39.416024184277596
# ------------------------------------------------------------------------
# for validation:
# RMSE: 2817.7784665409868
# MAE: 2013.7739572833955
# R² Score: 0.20434446496660108
# RMSPE:  40.51143234925152
# Ridge()

# %% [markdown]
# ***Lasso Regression***

# %%
from sklearn.linear_model import Lasso
try_model(Lasso())
# Out:
# for training:
# RMSE: 2741.714390464056
# MAE: 1996.3721051064788
# R² Score: 0.2082971987943728
# RMSPE:  39.41785288273597
# ------------------------------------------------------------------------
# for validation:
# RMSE: 2817.9472924045217
# MAE: 2013.0314030636687
# R² Score: 0.20424911946059343
# RMSPE:  40.51385957255194
# Lasso()

# %% [markdown]
# ***ElasticNet***

# %%
from sklearn.linear_model import ElasticNet
try_model(ElasticNet())
# Out:
# for training:
# RMSE: 2879.0432103903954
# MAE: 2089.4999808029593
# R² Score: 0.1270002393375681
# RMSPE:  41.392240601326876
# ------------------------------------------------------------------------
# for validation:
# RMSE: 2972.6658860503385
# MAE: 2114.072903411993
# R² Score: 0.11446935535165359
# RMSPE:  42.73826149558462
# ElasticNet()

# %% [markdown]
# ***SGD Regression***

# %%
from sklearn.linear_model import SGDRegressor
sgd_model=try_model(SGDRegressor())
# Out:
# for training:
# RMSE: 2742.349077944231
# MAE: 1990.5351110065424
# R² Score: 0.20793060917554085
# RMSPE:  39.42697783674542
# ------------------------------------------------------------------------
# for validation:
# RMSE: 2826.1646837207068
# MAE: 2010.9215186403544
# R² Score: 0.19960138843442932
# RMSPE:  40.632001682141414

# %% [markdown]
# ***Changing hyperparameters***

# %%
try_model(ElasticNet(alpha=0.9))
# Out:
# for training:
# RMSE: 2871.138494370456
# MAE: 2082.597707712468
# R² Score: 0.13178748373292037
# RMSPE:  41.278593850141746
# ------------------------------------------------------------------------
# for validation:
# RMSE: 2964.524371210543
# MAE: 2107.1498684710696
# R² Score: 0.11931328226108495
# RMSPE:  42.62121026832555
# ElasticNet(alpha=0.9)

# %% [markdown]
# ***Decision Tree***

# %%
from sklearn.tree import DecisionTreeRegressor
Dt_model=try_model(DecisionTreeRegressor(random_state=42,max_depth=34))
# Out:
# for training:
# RMSE: 423.5918001470125
# MAE: 117.00327391535167
# R² Score: 0.981102130420493
# RMSPE:  6.090014087026085
# ------------------------------------------------------------------------
# for validation:
# RMSE: 1566.7567356877478
# MAE: 1030.2336317330949
# R² Score: 0.7540116511444805
# RMSPE:  22.525390217586537

# %% [markdown]
# ***Random Forest***

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model_1=try_model(RandomForestRegressor(random_state=42))
# Out:
# for training:
# RMSE: 474.9198974666898
# MAE: 277.2403897399944
# R² Score: 0.9762448110469621
# RMSPE:  6.8279623561582845
# ------------------------------------------------------------------------
# for validation:
# RMSE: 1371.7321923469985
# MAE: 891.816501909066
# R² Score: 0.8114397877522707
# RMSPE:  19.72150634672599

# %%
print(rf_model_1)
# Out:
# RandomForestRegressor(random_state=42)

# %%
from sklearn.ensemble import RandomForestRegressor
rf_model_2=try_model(RandomForestRegressor(random_state=42,max_depth=34))
# Out:
# for training:
# RMSE: 517.29053626724
# MAE: 319.5137145015417
# R² Score: 0.9718170256890067
# RMSPE:  7.4371285087657935
# ------------------------------------------------------------------------
# for validation:
# RMSE: 1374.5882173495843
# MAE: 894.1840854404037
# R² Score: 0.8106537840241009
# RMSPE:  19.762567652663947

# %% [markdown]
# ******

# %% [markdown]
# ***Passing inputs for results***

# %%
num_cols=['Store', 'Day', 'Month', 'Year']
cat_cols=['DayOfWeek','Promo', 'StateHoliday', 'StoreType', 'Assortment']

from sklearn.impute import SimpleImputer
imputer=SimpleImputer(strategy='mean').fit(train_inputs[num_cols])

from sklearn.preprocessing import MinMaxScaler
scaler=MinMaxScaler().fit(train_inputs[num_cols])

from sklearn.preprocessing import OneHotEncoder
encoder=OneHotEncoder(sparse_output=False,handle_unknown='ignore').fit(train_inputs[cat_cols])
encoded_cols=list(encoder.get_feature_names_out(cat_cols))

# %%
def predict_inputs(model,inputs):
    if inputs['Open']==0:
        return 0
    input_df=pd.DataFrame([inputs])
    input_df['Date']=pd.to_datetime(input_df['Date'])
    input_df['Day']=input_df['Date'].dt.day
    input_df['Month']=input_df['Date'].dt.month
    input_df['Year']=input_df['Date'].dt.year
    input_df[num_cols]=imputer.transform(input_df[num_cols])
    input_df[num_cols]=scaler.transform(input_df[num_cols])
    input_df[encoded_cols]=encoder.transform(input_df[cat_cols])
    x_input=input_df[num_cols+encoded_cols]
    pred=model.predict(x_input)
    return pred[0]

# %%
sample_input={
    'Store': 1,
    'DayOfWeek': 1,
    'Date': '2015-07-01',
    'Open': 1,
    'Promo': 1,
    'StateHoliday': '0',
    'SchoolHoliday': 0,
    'StoreType': 'c',
    'Assortment': 'a',
    'CompetitionDistance': 1270.0,
    'CompetitionOpenSinceMonth': 9,
    'CompetitionOpenSinceYear': 2008,
    'Promo2': 0,
    'Promo2SinceWeek': np.nan,
    'Promo2SinceYear': np.nan,
    'PromoInterval': np.nan}
sample_input
# Out:
# {'Store': 1,
#  'DayOfWeek': 1,
#  'Date': '2015-07-01',
#  'Open': 1,
#  'Promo': 1,
#  'StateHoliday': '0',
#  'SchoolHoliday': 0,
#  'StoreType': 'c',
#  'Assortment': 'a',
#  'CompetitionDistance': 1270.0,
#  'CompetitionOpenSinceMonth': 9,
#  'CompetitionOpenSinceYear': 2008,
#  'Promo2': 0,
#  'Promo2SinceWeek': nan,
#  'Promo2SinceYear': nan,
#  'PromoInterval': nan}

# %%
predict_inputs(rf_model_1,sample_input)
# Out:
# np.float64(16741.29)

# %%
predict_inputs(rf_model_2,sample_input)
# Out:
# np.float64(16489.7)

# %% [markdown]
# ***Saving out test results to submissions***

# %%
submission_df=pd.read_csv('sample_submission.csv')
test_df=pd.read_csv('test.csv')
submission_df,test_df
# Out:
# (          Id  Sales
#  0          1      0
#  1          2      0
#  2          3      0
#  3          4      0
#  4          5      0
#  ...      ...    ...
#  41083  41084      0
#  41084  41085      0
#  41085  41086      0
#  41086  41087      0
#  41087  41088      0
#
#  [41088 rows x 2 columns],
#            Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
#  0          1      1          4  2015-09-17   1.0      1            0
#  1          2      3          4  2015-09-17   1.0      1            0
#  2          3      7          4  2015-09-17   1.0      1            0
#  3          4      8          4  2015-09-17   1.0      1            0
#  4          5      9          4  2015-09-17   1.0      1            0
#  ...      ...    ...        ...         ...   ...    ...          ...
#  41083  41084   1111          6  2015-08-01   1.0      0            0
#  41084  41085   1112          6  2015-08-01   1.0      0            0
# ...

# %%
test_preds=rf_model_1.predict(X_test)
test_preds
# Out:
# array([ 4258.01,  7713.83,  8775.7 , ...,  5954.68, 20823.07,  6748.48],
#       shape=(41088,))

# %%
submission_df['Sales']=test_df['Open'].fillna(1).astype('int')*test_preds

# %%
submission_df
# Out:
#           Id     Sales
# 0          1   4258.01
# 1          2   7713.83
# 2          3   8775.70
# 3          4   6775.37
# 4          5   6492.47
# ...      ...       ...
# 41083  41084   3052.40
# 41084  41085   9008.27
# 41085  41086   5954.68
# 41086  41087  20823.07
# 41087  41088   6748.48
#
# [41088 rows x 2 columns]

# %%
submission_df.to_csv('submission.csv',index=None)
