# %%
# pip install numpy pandas matplotlib seaborn xgboost graphviz lightgbm scikit-learn xgboost lightgbm --upgrade

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.9.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.7.14
# cffi                      1.17.1
# charset-normalizer        3.4.2
# click                     8.2.1
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.15
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fonttools                 4.59.0
# fqdn                      1.5.1
# graphviz                  0.21
# h11                       0.16.0
# httpcore                  1.0.9
# httpx                     0.28.1
# idna                      3.10
# ipykernel                 6.29.5
# ipython                   9.4.0
# ipython_pygments_lexers   1.1.1
# ipywidgets                8.1.7
# isoduration               20.11.0
# jedi                      0.19.2
# Jinja2                    3.1.6
# joblib                    1.5.1
# json5                     0.12.0
# jsonpointer               3.0.0
# jsonschema                4.24.1
# jsonschema-specifications 2025.4.1
# jupyter                   1.1.1
# jupyter_client            8.6.3
# jupyter-console           6.6.3
# jupyter_core              5.8.1
# jupyter-events            0.12.0
# jupyter-lsp               2.2.5
# jupyter_server            2.16.0
# jupyter_server_terminals  0.5.3
# jupyterlab                4.4.4
# jupyterlab_pygments       0.3.0
# jupyterlab_server         2.27.3
# jupyterlab_widgets        3.0.15
# kaggle                    1.7.4.5
# kiwisolver                1.4.8
# lightgbm                  4.6.0
# MarkupSafe                3.0.2
# matplotlib                3.10.3
# matplotlib-inline         0.1.7
# mistune                   3.1.3
# narwhals                  1.47.0
# nbclient                  0.10.2
# nbconvert                 7.16.6
# nbformat                  5.10.4
# nest-asyncio              1.6.0
# notebook                  7.4.4
# notebook_shim             0.2.4
# numpy                     2.3.2
# opendatasets              0.1.22
# overrides                 7.7.0
# packaging                 25.0
# pandas                    2.3.1
# pandocfilters             1.5.1
# parso                     0.8.4
# pillow                    11.3.0
# pip                       25.1.1
# platformdirs              4.3.8
# plotly                    6.2.0
# prometheus_client         0.22.1
# prompt_toolkit            3.0.51
# protobuf                  6.31.1
# psutil                    7.0.0
# pure_eval                 0.2.3
# pyarrow                   21.0.0
# pycparser                 2.22
# Pygments                  2.19.2
# pyparsing                 3.2.3
# python-dateutil           2.9.0.post0
# python-json-logger        3.3.0
# python-slugify            8.0.4
# pytz                      2025.2
# pywin32                   311
# pywinpty                  2.0.15
# PyYAML                    6.0.2
# pyzmq                     27.0.0
# referencing               0.36.2
# requests                  2.32.4
# rfc3339-validator         0.1.4
# rfc3986-validator         0.1.1
# rpds-py                   0.26.0
# scikit-learn              1.7.1
# scipy                     1.16.0
# seaborn                   0.13.2
# Send2Trash                1.8.3
# setuptools                80.9.0
# six                       1.17.0
# sniffio                   1.3.1
# soupsieve                 2.7
# stack-data                0.6.3
# terminado                 0.18.1
# text-unidecode            1.3
# threadpoolctl             3.6.0
# tinycss2                  1.4.0
# tornado                   6.5.1
# tqdm                      4.67.1
# traitlets                 5.14.3
# types-python-dateutil     2.9.0.20250708
# typing_extensions         4.14.1
# tzdata                    2025.2
# uri-template              1.3.0
# urllib3                   2.5.0
# wcwidth                   0.2.13
# webcolors                 24.11.1
# webencodings              0.5.1
# websocket-client          1.8.0
# widgetsnbextension        4.0.14
# xgboost                   3.0.2
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn import preprocessing
from urllib.request import urlretrieve
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',150)
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(10,6)
matplotlib.rcParams['figure.facecolor']='#00000000'

# %%
ross_df=pd.read_csv('train.csv',low_memory=False)
ross_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# 2                  0              1
# 3                  0              1
# 4                  0              1
# ...              ...            ...
# 1017204            a              1
# 1017205            a              1
# 1017206            a              1
# 1017207            a              1
# 1017208            a              1
#
# [1017209 rows x 9 columns]

# %%
ross_df.isna().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
ross_df.Store.value_counts()
# Out:
# Store
# 1115    942
# 1       942
# 2       942
# 3       942
# 4       942
#        ...
# 32      758
# 36      758
# 41      758
# 1092    758
# 1094    758
# Name: count, Length: 1115, dtype: int64

# %%
store_df=pd.read_csv('store.csv',low_memory=False)
store_df
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# 3                           9.0                    2009.0       0
# 4                           4.0                    2015.0       0
# ...                         ...                       ...     ...
# 1110                        6.0                    2014.0       1
# 1111                        4.0                    2006.0       0
# 1112                        NaN                       NaN       0
# 1113                        NaN                       NaN       0
# 1114                        NaN                       NaN       1
#
#       Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                 NaN              NaN               NaN
# 1                13.0           2010.0   Jan,Apr,Jul,Oct
# 2                14.0           2011.0   Jan,Apr,Jul,Oct
# 3                 NaN              NaN               NaN
# 4                 NaN              NaN               NaN
# ...               ...              ...               ...
# 1110             31.0           2013.0   Jan,Apr,Jul,Oct
# 1111              NaN              NaN               NaN
# 1112              NaN              NaN               NaN
# 1113              NaN              NaN               NaN
# 1114             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1115 rows x 10 columns]

# %%
store_df.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# ***Merging Train and Store data frame to have allt he inputs into a single dataframe***

# %%
merged_df=ross_df.merge(store_df,how='left',on='Store')
merged_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1017204            a              1         a          a               1900.0
# 1017205            a              1         c          c               1880.0
# 1017206            a              1         a          c               9260.0
# 1017207            a              1         a          c                870.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1017204                        6.0                    2014.0       1
# 1017205                        4.0                    2006.0       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                    NaN              NaN               NaN
# 1                   13.0           2010.0   Jan,Apr,Jul,Oct
# 2                   14.0           2011.0   Jan,Apr,Jul,Oct
# 3                    NaN              NaN               NaN
# 4                    NaN              NaN               NaN
# ...                  ...              ...               ...
# 1017204             31.0           2013.0   Jan,Apr,Jul,Oct
# 1017205              NaN              NaN               NaN
# 1017206              NaN              NaN               NaN
# 1017207              NaN              NaN               NaN
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [1017209 rows x 18 columns]

# %%
merged_df.isna().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
#  13  CompetitionOpenSinceYear   693861 non-null   float64
#  14  Promo2                     1017209 non-null  int64
#  15  Promo2SinceWeek            509178 non-null   float64
#  16  Promo2SinceYear            509178 non-null   float64
#  17  PromoInterval              509178 non-null   object
# dtypes: float64(5), int64(8), object(5)
# memory usage: 139.7+ MB

# %%
round(merged_df.describe().T,2)
# Out:
#                                count     mean      std     min     25%  \
# Store                      1017209.0   558.43   321.91     1.0   280.0
# DayOfWeek                  1017209.0     4.00     2.00     1.0     2.0
# Sales                      1017209.0  5773.82  3849.93     0.0  3727.0
# Customers                  1017209.0   633.15   464.41     0.0   405.0
# Open                       1017209.0     0.83     0.38     0.0     1.0
# Promo                      1017209.0     0.38     0.49     0.0     0.0
# SchoolHoliday              1017209.0     0.18     0.38     0.0     0.0
# CompetitionDistance        1014567.0  5430.09  7715.32    20.0   710.0
# CompetitionOpenSinceMonth   693861.0     7.22     3.21     1.0     4.0
# CompetitionOpenSinceYear    693861.0  2008.69     5.99  1900.0  2006.0
# Promo2                     1017209.0     0.50     0.50     0.0     0.0
# Promo2SinceWeek             509178.0    23.27    14.10     1.0    13.0
# Promo2SinceYear             509178.0  2011.75     1.66  2009.0  2011.0
#
#                               50%     75%      max
# Store                       558.0   838.0   1115.0
# DayOfWeek                     4.0     6.0      7.0
# Sales                      5744.0  7856.0  41551.0
# Customers                   609.0   837.0   7388.0
# Open                          1.0     1.0      1.0
# Promo                         0.0     1.0      1.0
# SchoolHoliday                 0.0     0.0      1.0
# CompetitionDistance        2330.0  6890.0  75860.0
# CompetitionOpenSinceMonth     8.0    10.0     12.0
# CompetitionOpenSinceYear   2010.0  2013.0   2015.0
# Promo2                        1.0     1.0      1.0
# Promo2SinceWeek              22.0    37.0     50.0
# Promo2SinceYear            2012.0  2013.0   2015.0

# %% [markdown]
# ***Merging Test and Store data frame to have allt he inputs into a single dataframe***

# %%
test_df=pd.read_csv('test.csv',low_memory=False)
test_df
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...              ...
# 41083              0
# 41084              0
# 41085              0
# 41086              0
# 41087              1
#
# [41088 rows x 8 columns]

# %%
merged_test_df=test_df.merge(store_df,how='left',on='Store')
merged_test_df
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0         c          a               1270.0
# 1                  0         a          a              14130.0
# 2                  0         a          c              24000.0
# 3                  0         a          a               7520.0
# 4                  0         a          c               2030.0
# ...              ...       ...        ...                  ...
# 41083              0         a          a               1900.0
# 41084              0         c          c               1880.0
# 41085              0         a          c               9260.0
# 41086              0         a          c                870.0
# 41087              1         d          c               5350.0
#
#        CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                            9.0                    2008.0       0
# 1                           12.0                    2006.0       1
# 2                            4.0                    2013.0       0
# 3                           10.0                    2014.0       0
# 4                            8.0                    2000.0       0
# ...                          ...                       ...     ...
# 41083                        6.0                    2014.0       1
# 41084                        4.0                    2006.0       0
# 41085                        NaN                       NaN       0
# 41086                        NaN                       NaN       0
# 41087                        NaN                       NaN       1
#
#        Promo2SinceWeek  Promo2SinceYear     PromoInterval
# 0                  NaN              NaN               NaN
# 1                 14.0           2011.0   Jan,Apr,Jul,Oct
# 2                  NaN              NaN               NaN
# 3                  NaN              NaN               NaN
# 4                  NaN              NaN               NaN
# ...                ...              ...               ...
# 41083             31.0           2013.0   Jan,Apr,Jul,Oct
# 41084              NaN              NaN               NaN
# 41085              NaN              NaN               NaN
# 41086              NaN              NaN               NaN
# 41087             22.0           2012.0  Mar,Jun,Sept,Dec
#
# [41088 rows x 17 columns]

# %%
merged_test_df.isna().sum()
# Out:
# Id                               0
# Store                            0
# DayOfWeek                        0
# Date                             0
# Open                            11
# Promo                            0
# StateHoliday                     0
# SchoolHoliday                    0
# StoreType                        0
# Assortment                       0
# CompetitionDistance             96
# CompetitionOpenSinceMonth    15216
# CompetitionOpenSinceYear     15216
# Promo2                           0
# Promo2SinceWeek              17232
# Promo2SinceYear              17232
# PromoInterval                17232
# dtype: int64

# %%
merged_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         41088 non-null  int64
#  1   Store                      41088 non-null  int64
#  2   DayOfWeek                  41088 non-null  int64
#  3   Date                       41088 non-null  object
#  4   Open                       41077 non-null  float64
#  5   Promo                      41088 non-null  int64
#  6   StateHoliday               41088 non-null  object
#  7   SchoolHoliday              41088 non-null  int64
#  8   StoreType                  41088 non-null  object
#  9   Assortment                 41088 non-null  object
#  10  CompetitionDistance        40992 non-null  float64
#  11  CompetitionOpenSinceMonth  25872 non-null  float64
#  12  CompetitionOpenSinceYear   25872 non-null  float64
#  13  Promo2                     41088 non-null  int64
#  14  Promo2SinceWeek            23856 non-null  float64
#  15  Promo2SinceYear            23856 non-null  float64
#  16  PromoInterval              23856 non-null  object
# dtypes: float64(6), int64(6), object(5)
# memory usage: 5.3+ MB

# %%
round(merged_test_df.describe().T,2)
# Out:
#                              count      mean       std     min       25%  \
# Id                         41088.0  20544.50  11861.23     1.0  10272.75
# Store                      41088.0    555.90    320.27     1.0    279.75
# DayOfWeek                  41088.0      3.98      2.02     1.0      2.00
# Open                       41077.0      0.85      0.35     0.0      1.00
# Promo                      41088.0      0.40      0.49     0.0      0.00
# SchoolHoliday              41088.0      0.44      0.50     0.0      0.00
# CompetitionDistance        40992.0   5088.58   7225.49    20.0    720.00
# CompetitionOpenSinceMonth  25872.0      7.04      3.14     1.0      4.00
# CompetitionOpenSinceYear   25872.0   2008.64      6.86  1900.0   2006.00
# Promo2                     41088.0      0.58      0.49     0.0      0.00
# Promo2SinceWeek            23856.0     24.43     14.16     1.0     13.00
# Promo2SinceYear            23856.0   2011.82      1.69  2009.0   2011.00
#
#                                50%       75%      max
# Id                         20544.5  30816.25  41088.0
# Store                        553.5    832.25   1115.0
# DayOfWeek                      4.0      6.00      7.0
# Open                           1.0      1.00      1.0
# Promo                          0.0      1.00      1.0
# SchoolHoliday                  0.0      1.00      1.0
# CompetitionDistance         2425.0   6480.00  75860.0
# CompetitionOpenSinceMonth      7.0      9.00     12.0
# CompetitionOpenSinceYear    2010.0   2012.00   2015.0
# Promo2                         1.0      1.00      1.0
# Promo2SinceWeek               22.0     37.00     49.0
# Promo2SinceYear             2012.0   2013.00   2015.0

# %% [markdown]
# ***Feature engineering***

# %%
def split_data(df):
    df['Date']=pd.to_datetime(df['Date'])
    df['Year']=df.Date.dt.year
    df['Month']=df.Date.dt.month
    df['Day']=df.Date.dt.day
    df['WeekOfYear']=df.Date.dt.isocalendar().week

# %%
split_data(merged_df)
split_data(merged_test_df)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1017204            a              1         a          a               1900.0
# 1017205            a              1         c          c               1880.0
# 1017206            a              1         a          c               9260.0
# 1017207            a              1         a          c                870.0
# 1017208            a              1         d          c               5350.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1017204                        6.0                    2014.0       1
# 1017205                        4.0                    2006.0       0
# 1017206                        NaN                       NaN       0
# 1017207                        NaN                       NaN       0
# 1017208                        NaN                       NaN       1
#
#          Promo2SinceWeek  Promo2SinceYear     PromoInterval  Year  Month  Day  \
# 0                    NaN              NaN               NaN  2015      7   31
# 1                   13.0           2010.0   Jan,Apr,Jul,Oct  2015      7   31
# 2                   14.0           2011.0   Jan,Apr,Jul,Oct  2015      7   31
# 3                    NaN              NaN               NaN  2015      7   31
# 4                    NaN              NaN               NaN  2015      7   31
# ...                  ...              ...               ...   ...    ...  ...
# 1017204             31.0           2013.0   Jan,Apr,Jul,Oct  2013      1    1
# 1017205              NaN              NaN               NaN  2013      1    1
# 1017206              NaN              NaN               NaN  2013      1    1
# 1017207              NaN              NaN               NaN  2013      1    1
# 1017208             22.0           2012.0  Mar,Jun,Sept,Dec  2013      1    1
#
#          WeekOfYear
# 0                31
# 1                31
# 2                31
# 3                31
# 4                31
# ...             ...
# 1017204           1
# 1017205           1
# 1017206           1
# 1017207           1
# 1017208           1
#
# [1017209 rows x 22 columns]

# %% [markdown]
# **Store open/close**

# %%
merged_df[merged_df.Open==0].Sales
# Out:
# 291        0
# 875        0
# 1406       0
# 1990       0
# 2521       0
#           ..
# 1017204    0
# 1017205    0
# 1017206    0
# 1017207    0
# 1017208    0
# Name: Sales, Length: 172817, dtype: int64

# %%
merged_df[merged_df.Open==0].Sales.value_counts()
# Out:
# Sales
# 0    172817
# Name: count, dtype: int64

# %% [markdown]
# all the sales are aero when the srorw is closed so i willl be better to remove all the rows when the store is closed

# %%
merged_df=merged_df[merged_df.Open==1].copy()
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1016776            a              1         b          a                150.0
# 1016827            a              1         b          b                860.0
# 1016863            a              1         b          b                840.0
# 1017042            a              1         b          b               1430.0
# 1017190            a              1         b          b                720.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1016776                        9.0                    2006.0       0
# 1016827                       10.0                    1999.0       0
# 1016863                        NaN                       NaN       1
# 1017042                        NaN                       NaN       0
# 1017190                        3.0                    2002.0       0
#
#          Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year  Month  Day  \
# 0                    NaN              NaN              NaN  2015      7   31
# 1                   13.0           2010.0  Jan,Apr,Jul,Oct  2015      7   31
# 2                   14.0           2011.0  Jan,Apr,Jul,Oct  2015      7   31
# 3                    NaN              NaN              NaN  2015      7   31
# 4                    NaN              NaN              NaN  2015      7   31
# ...                  ...              ...              ...   ...    ...  ...
# 1016776              NaN              NaN              NaN  2013      1    1
# 1016827              NaN              NaN              NaN  2013      1    1
# 1016863             48.0           2012.0  Jan,Apr,Jul,Oct  2013      1    1
# 1017042              NaN              NaN              NaN  2013      1    1
# 1017190              NaN              NaN              NaN  2013      1    1
#
#          WeekOfYear
# 0                31
# 1                31
# 2                31
# 3                31
# 4                31
# ...             ...
# 1016776           1
# 1016827           1
# 1016863           1
# 1017042           1
# 1017190           1
#
# [844392 rows x 22 columns]

# %% [markdown]
# **Competition**
#
# we are calculating number od=f munths the competitors are open using current date

# %%
def comp_monts(df):
    df['CompetitionOpen']=12*(df.Year-df.CompetitionOpenSinceYear) +(df.Month-df.CompetitionOpenSinceMonth)
    df['CompetitionOpen']=df.CompetitionOpen.map(lambda x:0 if x<0 else x).fillna(0)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1016776            a              1         b          a                150.0
# 1016827            a              1         b          b                860.0
# 1016863            a              1         b          b                840.0
# 1017042            a              1         b          b               1430.0
# 1017190            a              1         b          b                720.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1016776                        9.0                    2006.0       0
# 1016827                       10.0                    1999.0       0
# 1016863                        NaN                       NaN       1
# 1017042                        NaN                       NaN       0
# 1017190                        3.0                    2002.0       0
#
#          Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year  Month  Day  \
# 0                    NaN              NaN              NaN  2015      7   31
# 1                   13.0           2010.0  Jan,Apr,Jul,Oct  2015      7   31
# 2                   14.0           2011.0  Jan,Apr,Jul,Oct  2015      7   31
# 3                    NaN              NaN              NaN  2015      7   31
# 4                    NaN              NaN              NaN  2015      7   31
# ...                  ...              ...              ...   ...    ...  ...
# 1016776              NaN              NaN              NaN  2013      1    1
# 1016827              NaN              NaN              NaN  2013      1    1
# 1016863             48.0           2012.0  Jan,Apr,Jul,Oct  2013      1    1
# 1017042              NaN              NaN              NaN  2013      1    1
# 1017190              NaN              NaN              NaN  2013      1    1
#
#          WeekOfYear
# 0                31
# 1                31
# 2                31
# 3                31
# 4                31
# ...             ...
# 1016776           1
# 1016827           1
# 1016863           1
# 1017042           1
# 1017190           1
#
# [844392 rows x 22 columns]

# %%
comp_monts(merged_df)
comp_monts(merged_test_df)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1016776            a              1         b          a                150.0
# 1016827            a              1         b          b                860.0
# 1016863            a              1         b          b                840.0
# 1017042            a              1         b          b               1430.0
# 1017190            a              1         b          b                720.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1016776                        9.0                    2006.0       0
# 1016827                       10.0                    1999.0       0
# 1016863                        NaN                       NaN       1
# 1017042                        NaN                       NaN       0
# 1017190                        3.0                    2002.0       0
#
#          Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year  Month  Day  \
# 0                    NaN              NaN              NaN  2015      7   31
# 1                   13.0           2010.0  Jan,Apr,Jul,Oct  2015      7   31
# 2                   14.0           2011.0  Jan,Apr,Jul,Oct  2015      7   31
# 3                    NaN              NaN              NaN  2015      7   31
# 4                    NaN              NaN              NaN  2015      7   31
# ...                  ...              ...              ...   ...    ...  ...
# 1016776              NaN              NaN              NaN  2013      1    1
# 1016827              NaN              NaN              NaN  2013      1    1
# 1016863             48.0           2012.0  Jan,Apr,Jul,Oct  2013      1    1
# 1017042              NaN              NaN              NaN  2013      1    1
# 1017190              NaN              NaN              NaN  2013      1    1
#
#          WeekOfYear  CompetitionOpen
# 0                31             82.0
# 1                31             92.0
# 2                31            103.0
# 3                31             70.0
# 4                31              3.0
# ...             ...              ...
# 1016776           1             76.0
# 1016827           1            159.0
# 1016863           1              0.0
# 1017042           1              0.0
# 1017190           1            130.0
#
# [844392 rows x 23 columns]

# %% [markdown]
# **Adding pramotions**

# %%
def check_promo_month(row):
    month2str={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sept',10:'Oct',11:'Nov',12:'Dec'}
    try:
        months=(row['PromoInterval'] or '').split(',')
        if row['Promo2Open'] and month2str[row['Month']] in months:
            return 1
        else:
            return 0
    except Exception:
        return 0
def promo_cols(df):
    df['Promo2Open']=12*(df.Year-df.Promo2SinceYear)+((df.WeekOfYear-df.Promo2SinceWeek)/4)*df['Promo2']
    df['Promo2Open']=df.Promo2Open.map(lambda x:0 if x<0 else x).fillna(0)*df['Promo2']
    df['IsPromo2Month']=df.apply(check_promo_month,axis=1)*df['Promo2']

# %%
promo_cols(merged_df)
promo_cols(merged_test_df)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0              1         c          a               1270.0
# 1                  0              1         a          a                570.0
# 2                  0              1         a          a              14130.0
# 3                  0              1         c          c                620.0
# 4                  0              1         a          a              29910.0
# ...              ...            ...       ...        ...                  ...
# 1016776            a              1         b          a                150.0
# 1016827            a              1         b          b                860.0
# 1016863            a              1         b          b                840.0
# 1017042            a              1         b          b               1430.0
# 1017190            a              1         b          b                720.0
#
#          CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                              9.0                    2008.0       0
# 1                             11.0                    2007.0       1
# 2                             12.0                    2006.0       1
# 3                              9.0                    2009.0       0
# 4                              4.0                    2015.0       0
# ...                            ...                       ...     ...
# 1016776                        9.0                    2006.0       0
# 1016827                       10.0                    1999.0       0
# 1016863                        NaN                       NaN       1
# 1017042                        NaN                       NaN       0
# 1017190                        3.0                    2002.0       0
#
#          Promo2SinceWeek  Promo2SinceYear    PromoInterval  Year  Month  Day  \
# 0                    NaN              NaN              NaN  2015      7   31
# 1                   13.0           2010.0  Jan,Apr,Jul,Oct  2015      7   31
# 2                   14.0           2011.0  Jan,Apr,Jul,Oct  2015      7   31
# 3                    NaN              NaN              NaN  2015      7   31
# 4                    NaN              NaN              NaN  2015      7   31
# ...                  ...              ...              ...   ...    ...  ...
# 1016776              NaN              NaN              NaN  2013      1    1
# 1016827              NaN              NaN              NaN  2013      1    1
# 1016863             48.0           2012.0  Jan,Apr,Jul,Oct  2013      1    1
# 1017042              NaN              NaN              NaN  2013      1    1
# 1017190              NaN              NaN              NaN  2013      1    1
#
#          WeekOfYear  CompetitionOpen  Promo2Open  IsPromo2Month
# 0                31             82.0        0.00              0
# 1                31             92.0       64.50              1
# 2                31            103.0       52.25              1
# 3                31             70.0        0.00              0
# 4                31              3.0        0.00              0
# ...             ...              ...         ...            ...
# 1016776           1             76.0        0.00              0
# 1016827           1            159.0        0.00              0
# 1016863           1              0.0        0.25              1
# 1017042           1              0.0        0.00              0
# 1017190           1            130.0        0.00              0
#
# [844392 rows x 25 columns]

# %%
merged_df.iloc[168074]
# Out:
# Store                                        807
# DayOfWeek                                      6
# Date                         2015-01-31 00:00:00
# Sales                                      11018
# Customers                                   1033
# Open                                           1
# Promo                                          0
# StateHoliday                                   0
# SchoolHoliday                                  0
# StoreType                                      a
# Assortment                                     a
# CompetitionDistance                       3870.0
# CompetitionOpenSinceMonth                    4.0
# CompetitionOpenSinceYear                  2008.0
# Promo2                                         0
# Promo2SinceWeek                              NaN
# Promo2SinceYear                              NaN
# PromoInterval                                NaN
# Year                                        2015
# Month                                          1
# Day                                           31
# WeekOfYear                                     5
# CompetitionOpen                             81.0
# Promo2Open                                   0.0
# IsPromo2Month                                  0
# Name: 202621, dtype: object

# %% [markdown]
# **Diving target and input columns**

# %%
merged_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Year', 'Month', 'Day',
#        'WeekOfYear', 'CompetitionOpen', 'Promo2Open', 'IsPromo2Month'],
#       dtype='object')

# %%
inputs_cols=['Store', 'DayOfWeek', 'Promo',
       'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
       'CompetitionDistance', 'CompetitionOpen', 'Year', 'Month', 'Day', 'WeekOfYear', 'Promo2', 'Promo2Open', 'IsPromo2Month']
target_cols='Sales'

# %%
inputs=merged_df[inputs_cols].copy()
targets=merged_df[target_cols].copy()

# %%
inputs
# Out:
#          Store  DayOfWeek  Promo StateHoliday  SchoolHoliday StoreType  \
# 0            1          5      1            0              1         c
# 1            2          5      1            0              1         a
# 2            3          5      1            0              1         a
# 3            4          5      1            0              1         c
# 4            5          5      1            0              1         a
# ...        ...        ...    ...          ...            ...       ...
# 1016776    682          2      0            a              1         b
# 1016827    733          2      0            a              1         b
# 1016863    769          2      0            a              1         b
# 1017042    948          2      0            a              1         b
# 1017190   1097          2      0            a              1         b
#
#         Assortment  CompetitionDistance  CompetitionOpen  Year  Month  Day  \
# 0                a               1270.0             82.0  2015      7   31
# 1                a                570.0             92.0  2015      7   31
# 2                a              14130.0            103.0  2015      7   31
# 3                c                620.0             70.0  2015      7   31
# 4                a              29910.0              3.0  2015      7   31
# ...            ...                  ...              ...   ...    ...  ...
# 1016776          a                150.0             76.0  2013      1    1
# 1016827          b                860.0            159.0  2013      1    1
# 1016863          b                840.0              0.0  2013      1    1
# 1017042          b               1430.0              0.0  2013      1    1
# 1017190          b                720.0            130.0  2013      1    1
#
#          WeekOfYear  Promo2  Promo2Open  IsPromo2Month
# 0                31       0        0.00              0
# 1                31       1       64.50              1
# 2                31       1       52.25              1
# 3                31       0        0.00              0
# 4                31       0        0.00              0
# ...             ...     ...         ...            ...
# 1016776           1       0        0.00              0
# 1016827           1       0        0.00              0
# 1016863           1       1        0.25              1
# 1017042           1       0        0.00              0
# 1017190           1       0        0.00              0
#
# [844392 rows x 16 columns]

# %%
targets
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1016776     3375
# 1016827    10765
# 1016863     5035
# 1017042     4491
# 1017190     5961
# Name: Sales, Length: 844392, dtype: int64

# %%
test_inputs=merged_test_df[inputs_cols]
test_inputs
# Out:
#        Store  DayOfWeek  Promo StateHoliday  SchoolHoliday StoreType  \
# 0          1          4      1            0              0         c
# 1          3          4      1            0              0         a
# 2          7          4      1            0              0         a
# 3          8          4      1            0              0         a
# 4          9          4      1            0              0         a
# ...      ...        ...    ...          ...            ...       ...
# 41083   1111          6      0            0              0         a
# 41084   1112          6      0            0              0         c
# 41085   1113          6      0            0              0         a
# 41086   1114          6      0            0              0         a
# 41087   1115          6      0            0              1         d
#
#       Assortment  CompetitionDistance  CompetitionOpen  Year  Month  Day  \
# 0              a               1270.0             84.0  2015      9   17
# 1              a              14130.0            105.0  2015      9   17
# 2              c              24000.0             29.0  2015      9   17
# 3              a               7520.0             11.0  2015      9   17
# 4              c               2030.0            181.0  2015      9   17
# ...          ...                  ...              ...   ...    ...  ...
# 41083          a               1900.0             14.0  2015      8    1
# 41084          c               1880.0            112.0  2015      8    1
# 41085          c               9260.0              0.0  2015      8    1
# 41086          c                870.0              0.0  2015      8    1
# 41087          c               5350.0              0.0  2015      8    1
#
#        WeekOfYear  Promo2  Promo2Open  IsPromo2Month
# 0              38       0        0.00              0
# 1              38       1       54.00              0
# 2              38       0        0.00              0
# 3              38       0        0.00              0
# 4              38       0        0.00              0
# ...           ...     ...         ...            ...
# 41083          31       1       24.00              0
# 41084          31       0        0.00              0
# 41085          31       0        0.00              0
# 41086          31       0        0.00              0
# 41087          31       1       38.25              0
#
# [41088 rows x 16 columns]

# %%
num_cols=['Store', 'Promo',
       'SchoolHoliday',
       'CompetitionDistance', 'CompetitionOpen', 'Year', 'Month', 'Day', 'WeekOfYear', 'Promo2', 'Promo2Open', 'IsPromo2Month']
cat_cols=['DayOfWeek', 'StateHoliday', 'StoreType', 'Assortment']

# %%
inputs[num_cols].isna().sum()
# Out:
# Store                     0
# Promo                     0
# SchoolHoliday             0
# CompetitionDistance    2186
# CompetitionOpen           0
# Year                      0
# Month                     0
# Day                       0
# WeekOfYear                0
# Promo2                    0
# Promo2Open                0
# IsPromo2Month             0
# dtype: int64

# %%
test_inputs[num_cols].isna().sum()
# Out:
# Store                   0
# Promo                   0
# SchoolHoliday           0
# CompetitionDistance    96
# CompetitionOpen         0
# Year                    0
# Month                   0
# Day                     0
# WeekOfYear              0
# Promo2                  0
# Promo2Open              0
# IsPromo2Month           0
# dtype: int64

# %%
max_distance=inputs.CompetitionDistance.max()
inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
test_inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\2640819914.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\2640819914.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   test_inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\2640819914.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)

# %%
inputs[num_cols].isna().sum()
# Out:
# Store                  0
# Promo                  0
# SchoolHoliday          0
# CompetitionDistance    0
# CompetitionOpen        0
# Year                   0
# Month                  0
# Day                    0
# WeekOfYear             0
# Promo2                 0
# Promo2Open             0
# IsPromo2Month          0
# dtype: int64

# %%
test_inputs[num_cols].isna().sum()
# Out:
# Store                  0
# Promo                  0
# SchoolHoliday          0
# CompetitionDistance    0
# CompetitionOpen        0
# Year                   0
# Month                  0
# Day                    0
# WeekOfYear             0
# Promo2                 0
# Promo2Open             0
# IsPromo2Month          0
# dtype: int64

# %% [markdown]
# **scaling the data**

# %%
inputs[num_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 844392 entries, 0 to 1017190
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Store                844392 non-null  int64
#  1   Promo                844392 non-null  int64
#  2   SchoolHoliday        844392 non-null  int64
#  3   CompetitionDistance  844392 non-null  float64
#  4   CompetitionOpen      844392 non-null  float64
#  5   Year                 844392 non-null  int32
#  6   Month                844392 non-null  int32
#  7   Day                  844392 non-null  int32
#  8   WeekOfYear           844392 non-null  UInt32
#  9   Promo2               844392 non-null  int64
#  10  Promo2Open           844392 non-null  float64
#  11  IsPromo2Month        844392 non-null  int64
# dtypes: UInt32(1), float64(3), int32(3), int64(5)
# memory usage: 71.7 MB

# %%
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
scaler=MinMaxScaler().fit(inputs[num_cols])
encoder=OneHotEncoder(sparse_output=False,handle_unknown='ignore').fit(inputs[cat_cols])
encoded_cols=list(encoder.get_feature_names_out(cat_cols))

# %%
inputs[num_cols]=scaler.transform(inputs[num_cols])
test_inputs[num_cols]=scaler.transform(test_inputs[num_cols])
inputs[encoded_cols]=encoder.transform(inputs[cat_cols])
test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[num_cols]=scaler.transform(test_inputs[num_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_4248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])

# %%
inputs.describe()
# Out:
#                Store      DayOfWeek          Promo  SchoolHoliday  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean        0.500380       3.520361       0.446352       0.193580
# std         0.288808       1.723689       0.497114       0.395103
# min         0.000000       1.000000       0.000000       0.000000
# 25%         0.250449       2.000000       0.000000       0.000000
# 50%         0.500000       3.000000       0.000000       0.000000
# 75%         0.750449       5.000000       1.000000       0.000000
# max         1.000000       7.000000       1.000000       1.000000
#
#        CompetitionDistance  CompetitionOpen           Year          Month  \
# count        844392.000000    844392.000000  844392.000000  844392.000000
# mean              0.038343         0.030270       0.415969       0.440522
# std               0.071018         0.047034       0.388630       0.302176
# min               0.000000         0.000000       0.000000       0.000000
# 25%               0.004548         0.000000       0.000000       0.181818
# 50%               0.015227         0.011544       0.500000       0.454545
# 75%               0.045419         0.052670       0.500000       0.636364
# max               1.000000         1.000000       1.000000       1.000000
#
#                  Day     WeekOfYear         Promo2     Promo2Open  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean        0.494523       0.444055       0.498684       0.181293
# std         0.289449       0.282153       0.499999       0.263520
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.233333       0.196078       0.000000       0.000000
# 50%         0.500000       0.431373       0.000000       0.000000
# 75%         0.733333       0.666667       1.000000       0.347222
# max         1.000000       1.000000       1.000000       1.000000
#
#        IsPromo2Month    DayOfWeek_1    DayOfWeek_2    DayOfWeek_3  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean        0.148921       0.162910       0.170491       0.168093
# std         0.356011       0.369284       0.376064       0.373949
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#          DayOfWeek_4    DayOfWeek_5    DayOfWeek_6    DayOfWeek_7  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean        0.159457       0.164189       0.170606       0.004255
# std         0.366102       0.370447       0.376164       0.065092
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         0.000000       0.000000       0.000000       0.000000
# 75%         0.000000       0.000000       0.000000       0.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#        StateHoliday_0  StateHoliday_a  StateHoliday_b  StateHoliday_c  \
# count   844392.000000   844392.000000   844392.000000   844392.000000
# mean         0.998922        0.000822        0.000172        0.000084
# std          0.032811        0.028657        0.013103        0.009169
# min          0.000000        0.000000        0.000000        0.000000
# 25%          1.000000        0.000000        0.000000        0.000000
# 50%          1.000000        0.000000        0.000000        0.000000
# 75%          1.000000        0.000000        0.000000        0.000000
# max          1.000000        1.000000        1.000000        1.000000
#
#          StoreType_a    StoreType_b    StoreType_c    StoreType_d  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean        0.541309       0.018431       0.133798       0.306462
# std         0.498291       0.134504       0.340435       0.461024
# min         0.000000       0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000       0.000000
# 75%         1.000000       0.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000       1.000000
#
#         Assortment_a   Assortment_b   Assortment_c
# count  844392.000000  844392.000000  844392.000000
# mean        0.526899       0.009725       0.463376
# std         0.499276       0.098136       0.498657
# min         0.000000       0.000000       0.000000
# 25%         0.000000       0.000000       0.000000
# 50%         1.000000       0.000000       0.000000
# 75%         1.000000       0.000000       1.000000
# max         1.000000       1.000000       1.000000

# %% [markdown]
# ***Training a model***

# %%
X=inputs[num_cols+encoded_cols]
X_test=test_inputs[num_cols+encoded_cols]

# %%
from xgboost import XGBRegressor

# %%
model=XGBRegressor(random_state=41,n_jobs=-1,n_estimators=20,max_depth=4).fit(X,targets)

# %%
pred=model.predict(X)
pred
# Out:
# array([ 8161.051 ,  7379.584 ,  8871.791 , ...,  9311.399 ,  7845.6377,
#        10193.34  ], shape=(844392,), dtype=float32)

# %%
from sklearn.metrics import root_mean_squared_error
def rmse(a,b):
    return root_mean_squared_error(a,b)
rmse(pred,targets)
# Out:
# 2404.82080078125

# %%
plt.hist(merged_df.Sales.sample(10000))
# Out:
# (array([ 340., 3557., 3834., 1519.,  468.,  166.,   71.,   27.,   14.,
#            4.]),
#  array([    0. ,  2858.4,  5716.8,  8575.2, 11433.6, 14292. , 17150.4,
#         20008.8, 22867.2, 25725.6, 28584. ]),
#  <BarContainer object of 10 artists>)

# %%
importance_df=pd.DataFrame({
    'features':X.columns,
    'importance':model.feature_importances_
})
importance_df.sort_values('importance',ascending=False).head(10)
# Out:
#                features  importance
# 1                 Promo    0.324344
# 12          DayOfWeek_1    0.093225
# 24          StoreType_b    0.072926
# 9                Promo2    0.044190
# 26          StoreType_d    0.044110
# 27         Assortment_a    0.041091
# 3   CompetitionDistance    0.037454
# 6                 Month    0.032448
# 8            WeekOfYear    0.030161
# 2         SchoolHoliday    0.029284

# %%
plt.figure(figsize=(10,6))
plt.title("importance graph")
sns.barplot(data=importance_df.sort_values('importance',ascending=False).head(10),x='importance',y='features')
# Out:
# <Axes: title={'center': 'importance graph'}, xlabel='importance', ylabel='features'>

# %% [markdown]
# ***K-FOLD Cross Validation***

# %%
def train_and_evaluate(X_train,train_targets,X_val,val_targets,**params):
    model=XGBRegressor(random_state=42,n_jobs=-1,**params).fit(X_train,train_targets)
    train_rmse=rmse(model.predict(X_train),train_targets)
    val_rmse=rmse(model.predict(X_val),val_targets)
    return model,train_rmse,val_rmse

# %%
from sklearn.model_selection import KFold
kFold=KFold(n_splits=5)
models=[]
for train_idxs,val_idxs in kFold.split(X):
    X_train,train_targets=X.iloc[train_idxs],targets.iloc[train_idxs]
    X_val,val_targets=X.iloc[val_idxs],targets.iloc[val_idxs]
    model,train_rmse,val_rmse=train_and_evaluate(X_train,train_targets,X_val,val_targets,max_depth=4,n_estimators=20)
    models.append(model)
    print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse,val_rmse))
# Out:
# Train RMSE: 2390.99560546875, Validation RMSE: 2461.603515625
# Train RMSE: 2383.4375, Validation RMSE: 2418.56298828125
# Train RMSE: 2366.869873046875, Validation RMSE: 2336.755126953125
# Train RMSE: 2389.548583984375, Validation RMSE: 2488.663330078125
# Train RMSE: 2374.4306640625, Validation RMSE: 2453.164794921875

# %%
def pred_avg(models,inputs):
    return np.mean([model.predict(inputs) for model in models],axis=0)

# %%
preds=pred_avg(models,X)
preds_vals=pred

# %%
rmse(preds,targets)
# Out:
# 1139.278076171875

# %% [markdown]
# ***Training again***

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,train_targets,val_targets=train_test_split(X,targets,test_size=0.1)

# %%
def test_params(**params):
    model=XGBRegressor(n_jobs=-1,random_state=42,**params).fit(X_train,train_targets)
    train_rmse=rmse(model.predict(X_train),train_targets)
    val_rmse=rmse(model.predict(X_val),val_targets)
    print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse,val_rmse))

# %% [markdown]
# **n_estimaters**

# %%
test_params(n_estimators=10)
test_params(n_estimators=30)
test_params(n_estimators=100)
test_params(n_estimators=200)
test_params(n_estimators=240)
test_params(n_estimators=300)
# Out:
# Train RMSE: 2350.02197265625, Validation RMSE: 2349.872314453125
# Train RMSE: 1871.45458984375, Validation RMSE: 1882.057861328125
# Train RMSE: 1175.99072265625, Validation RMSE: 1189.191162109375
# Train RMSE: 946.11962890625, Validation RMSE: 965.8446655273438
# Train RMSE: 902.2357177734375, Validation RMSE: 924.6570434570312
# Train RMSE: 856.382568359375, Validation RMSE: 882.8805541992188

# %% [markdown]
# **max_depth**

# %%
test_params(n_estimators=100, max_depth=5)
test_params(n_estimators=100, max_depth=10)
test_params(n_estimators=100, max_depth=11)
test_params(n_estimators=100, max_depth=12)
test_params(n_estimators=100, max_depth=13)
test_params(n_estimators=100, max_depth=14)
# Out:
# Train RMSE: 1427.1680908203125, Validation RMSE: 1692.6927490234375
# Train RMSE: 667.0288696289062, Validation RMSE: 1301.5535888671875
# Train RMSE: 582.455810546875, Validation RMSE: 1262.701171875
# Train RMSE: 493.25177001953125, Validation RMSE: 1298.488525390625
# Train RMSE: 418.86529541015625, Validation RMSE: 1266.0750732421875
# Train RMSE: 359.89031982421875, Validation RMSE: 1300.8489990234375

# %% [markdown]
# **Learning rate**

# %%
test_params(n_estimators=100, learning_rate=0.1)
test_params(n_estimators=100, learning_rate=0.3)
test_params(n_estimators=100, learning_rate=0.4)
test_params(n_estimators=100, learning_rate=0.5)
test_params(n_estimators=100, learning_rate=0.6)
test_params(n_estimators=100, learning_rate=0.75)
test_params(n_estimators=100, learning_rate=0.99)
# Out:
# Train RMSE: 1845.68212890625, Validation RMSE: 2009.1962890625
# Train RMSE: 1173.242431640625, Validation RMSE: 1502.2330322265625
# Train RMSE: 1046.8876953125, Validation RMSE: 1417.0703125
# Train RMSE: 998.6985473632812, Validation RMSE: 1399.622314453125
# Train RMSE: 960.704345703125, Validation RMSE: 1416.862548828125
# Train RMSE: 962.5391845703125, Validation RMSE: 1430.50830078125
# Train RMSE: 957.796630859375, Validation RMSE: 1578.1956787109375

# %%
test_params(n_estimators=300, max_depth=13, learning_rate=0.6)
test_params(n_estimators=300, max_depth=12, learning_rate=0.7)
test_params(n_estimators=300, max_depth=12, learning_rate=0.6)
test_params(n_estimators=300, max_depth=11, learning_rate=0.5)
test_params(n_estimators=300, max_depth=10, learning_rate=0.4)
test_params(n_estimators=300, max_depth=10, learning_rate=0.45)
test_params(n_estimators=300, max_depth=9, learning_rate=0.45)
# Out:
# Train RMSE: 118.62734985351562, Validation RMSE: 1442.2222900390625
# Train RMSE: 184.68679809570312, Validation RMSE: 1452.3623046875

# %% [markdown]
# ***Booster***

# %%
test_params(booster='gblinear')
# Out:
# Train RMSE: 2736.3583984375, Validation RMSE: 2701.413330078125
