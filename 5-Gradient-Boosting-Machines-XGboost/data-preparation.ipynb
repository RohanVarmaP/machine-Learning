# %%
# pip install numpy pandas matplotlib seaborn xgboost graphviz lightgbm scikit-learn xgboost lightgbm --upgrade

# %%
pip list
# Out:
# Package                   Version
# ------------------------- --------------
# anyio                     4.9.0
# argon2-cffi               25.1.0
# argon2-cffi-bindings      21.2.0
# arrow                     1.3.0
# asttokens                 3.0.0
# async-lru                 2.0.5
# attrs                     25.3.0
# babel                     2.17.0
# beautifulsoup4            4.13.4
# bleach                    6.2.0
# certifi                   2025.7.14
# cffi                      1.17.1
# charset-normalizer        3.4.2
# click                     8.2.1
# colorama                  0.4.6
# comm                      0.2.2
# contourpy                 1.3.2
# cycler                    0.12.1
# debugpy                   1.8.15
# decorator                 5.2.1
# defusedxml                0.7.1
# executing                 2.2.0
# fastjsonschema            2.21.1
# fonttools                 4.59.0
# fqdn                      1.5.1
# graphviz                  0.21
# ...

# %%
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression,SGDRegressor
from sklearn import preprocessing
from urllib.request import urlretrieve
import plotly.express as px
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.io as pio
# %matplotlib inline

pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',150)
sns.set_style('darkgrid')
matplotlib.rcParams['font.size']=14
matplotlib.rcParams['figure.figsize']=(10,6)
matplotlib.rcParams['figure.facecolor']='#00000000'

# %%
ross_df=pd.read_csv('train.csv',low_memory=False)
ross_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday
# 0                  0              1
# 1                  0              1
# ...

# %%
ross_df.isna().sum()
# Out:
# Store            0
# DayOfWeek        0
# Date             0
# Sales            0
# Customers        0
# Open             0
# Promo            0
# StateHoliday     0
# SchoolHoliday    0
# dtype: int64

# %%
ross_df.Store.value_counts()
# Out:
# Store
# 1115    942
# 1       942
# 2       942
# 3       942
# 4       942
#        ...
# 32      758
# 36      758
# 41      758
# 1092    758
# 1094    758
# Name: count, Length: 1115, dtype: int64

# %%
store_df=pd.read_csv('store.csv',low_memory=False)
store_df
# Out:
#       Store StoreType Assortment  CompetitionDistance  \
# 0         1         c          a               1270.0
# 1         2         a          a                570.0
# 2         3         a          a              14130.0
# 3         4         c          c                620.0
# 4         5         a          a              29910.0
# ...     ...       ...        ...                  ...
# 1110   1111         a          a               1900.0
# 1111   1112         c          c               1880.0
# 1112   1113         a          c               9260.0
# 1113   1114         a          c                870.0
# 1114   1115         d          c               5350.0
#
#       CompetitionOpenSinceMonth  CompetitionOpenSinceYear  Promo2  \
# 0                           9.0                    2008.0       0
# 1                          11.0                    2007.0       1
# 2                          12.0                    2006.0       1
# ...

# %%
store_df.isna().sum()
# Out:
# Store                          0
# StoreType                      0
# Assortment                     0
# CompetitionDistance            3
# CompetitionOpenSinceMonth    354
# CompetitionOpenSinceYear     354
# Promo2                         0
# Promo2SinceWeek              544
# Promo2SinceYear              544
# PromoInterval                544
# dtype: int64

# %% [markdown]
# ***Merging Train and Store data frame to have allt he inputs into a single dataframe***

# %%
merged_df=ross_df.merge(store_df,how='left',on='Store')
merged_df
# Out:
#          Store  DayOfWeek        Date  Sales  Customers  Open  Promo  \
# 0            1          5  2015-07-31   5263        555     1      1
# 1            2          5  2015-07-31   6064        625     1      1
# 2            3          5  2015-07-31   8314        821     1      1
# 3            4          5  2015-07-31  13995       1498     1      1
# 4            5          5  2015-07-31   4822        559     1      1
# ...        ...        ...         ...    ...        ...   ...    ...
# 1017204   1111          2  2013-01-01      0          0     0      0
# 1017205   1112          2  2013-01-01      0          0     0      0
# 1017206   1113          2  2013-01-01      0          0     0      0
# 1017207   1114          2  2013-01-01      0          0     0      0
# 1017208   1115          2  2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
merged_df.isna().sum()
# Out:
# Store                             0
# DayOfWeek                         0
# Date                              0
# Sales                             0
# Customers                         0
# Open                              0
# Promo                             0
# StateHoliday                      0
# SchoolHoliday                     0
# StoreType                         0
# Assortment                        0
# CompetitionDistance            2642
# CompetitionOpenSinceMonth    323348
# CompetitionOpenSinceYear     323348
# Promo2                            0
# Promo2SinceWeek              508031
# Promo2SinceYear              508031
# PromoInterval                508031
# dtype: int64

# %%
merged_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
merged_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1017209 entries, 0 to 1017208
# Data columns (total 18 columns):
#  #   Column                     Non-Null Count    Dtype
# ---  ------                     --------------    -----
#  0   Store                      1017209 non-null  int64
#  1   DayOfWeek                  1017209 non-null  int64
#  2   Date                       1017209 non-null  object
#  3   Sales                      1017209 non-null  int64
#  4   Customers                  1017209 non-null  int64
#  5   Open                       1017209 non-null  int64
#  6   Promo                      1017209 non-null  int64
#  7   StateHoliday               1017209 non-null  object
#  8   SchoolHoliday              1017209 non-null  int64
#  9   StoreType                  1017209 non-null  object
#  10  Assortment                 1017209 non-null  object
#  11  CompetitionDistance        1014567 non-null  float64
#  12  CompetitionOpenSinceMonth  693861 non-null   float64
# ...

# %%
round(merged_df.describe().T,2)
# Out:
#                                count     mean      std     min     25%  \
# Store                      1017209.0   558.43   321.91     1.0   280.0
# DayOfWeek                  1017209.0     4.00     2.00     1.0     2.0
# Sales                      1017209.0  5773.82  3849.93     0.0  3727.0
# Customers                  1017209.0   633.15   464.41     0.0   405.0
# Open                       1017209.0     0.83     0.38     0.0     1.0
# Promo                      1017209.0     0.38     0.49     0.0     0.0
# SchoolHoliday              1017209.0     0.18     0.38     0.0     0.0
# CompetitionDistance        1014567.0  5430.09  7715.32    20.0   710.0
# CompetitionOpenSinceMonth   693861.0     7.22     3.21     1.0     4.0
# CompetitionOpenSinceYear    693861.0  2008.69     5.99  1900.0  2006.0
# Promo2                     1017209.0     0.50     0.50     0.0     0.0
# Promo2SinceWeek             509178.0    23.27    14.10     1.0    13.0
# ...

# %% [markdown]
# ***Merging Test and Store data frame to have allt he inputs into a single dataframe***

# %%
test_df=pd.read_csv('test.csv',low_memory=False)
test_df
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday
# 0                  0
# 1                  0
# 2                  0
# 3                  0
# 4                  0
# ...

# %%
merged_test_df=test_df.merge(store_df,how='left',on='Store')
merged_test_df
# Out:
#           Id  Store  DayOfWeek        Date  Open  Promo StateHoliday  \
# 0          1      1          4  2015-09-17   1.0      1            0
# 1          2      3          4  2015-09-17   1.0      1            0
# 2          3      7          4  2015-09-17   1.0      1            0
# 3          4      8          4  2015-09-17   1.0      1            0
# 4          5      9          4  2015-09-17   1.0      1            0
# ...      ...    ...        ...         ...   ...    ...          ...
# 41083  41084   1111          6  2015-08-01   1.0      0            0
# 41084  41085   1112          6  2015-08-01   1.0      0            0
# 41085  41086   1113          6  2015-08-01   1.0      0            0
# 41086  41087   1114          6  2015-08-01   1.0      0            0
# 41087  41088   1115          6  2015-08-01   1.0      0            0
#
#        SchoolHoliday StoreType Assortment  CompetitionDistance  \
# 0                  0         c          a               1270.0
# ...

# %%
merged_test_df.isna().sum()
# Out:
# Id                               0
# Store                            0
# DayOfWeek                        0
# Date                             0
# Open                            11
# Promo                            0
# StateHoliday                     0
# SchoolHoliday                    0
# StoreType                        0
# Assortment                       0
# CompetitionDistance             96
# CompetitionOpenSinceMonth    15216
# CompetitionOpenSinceYear     15216
# Promo2                           0
# Promo2SinceWeek              17232
# Promo2SinceYear              17232
# PromoInterval                17232
# dtype: int64

# %%
merged_test_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 41088 entries, 0 to 41087
# Data columns (total 17 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Id                         41088 non-null  int64
#  1   Store                      41088 non-null  int64
#  2   DayOfWeek                  41088 non-null  int64
#  3   Date                       41088 non-null  object
#  4   Open                       41077 non-null  float64
#  5   Promo                      41088 non-null  int64
#  6   StateHoliday               41088 non-null  object
#  7   SchoolHoliday              41088 non-null  int64
#  8   StoreType                  41088 non-null  object
#  9   Assortment                 41088 non-null  object
#  10  CompetitionDistance        40992 non-null  float64
#  11  CompetitionOpenSinceMonth  25872 non-null  float64
#  12  CompetitionOpenSinceYear   25872 non-null  float64
# ...

# %%
round(merged_test_df.describe().T,2)
# Out:
#                              count      mean       std     min       25%  \
# Id                         41088.0  20544.50  11861.23     1.0  10272.75
# Store                      41088.0    555.90    320.27     1.0    279.75
# DayOfWeek                  41088.0      3.98      2.02     1.0      2.00
# Open                       41077.0      0.85      0.35     0.0      1.00
# Promo                      41088.0      0.40      0.49     0.0      0.00
# SchoolHoliday              41088.0      0.44      0.50     0.0      0.00
# CompetitionDistance        40992.0   5088.58   7225.49    20.0    720.00
# CompetitionOpenSinceMonth  25872.0      7.04      3.14     1.0      4.00
# CompetitionOpenSinceYear   25872.0   2008.64      6.86  1900.0   2006.00
# Promo2                     41088.0      0.58      0.49     0.0      0.00
# Promo2SinceWeek            23856.0     24.43     14.16     1.0     13.00
# Promo2SinceYear            23856.0   2011.82      1.69  2009.0   2011.00
#
# ...

# %% [markdown]
# ***Feature engineering***

# %%
def split_data(df):
    df['Date']=pd.to_datetime(df['Date'])
    df['Year']=df.Date.dt.year
    df['Month']=df.Date.dt.month
    df['Day']=df.Date.dt.day
    df['WeekOfYear']=df.Date.dt.isocalendar().week

# %%
split_data(merged_df)
split_data(merged_test_df)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1017204   1111          2 2013-01-01      0          0     0      0
# 1017205   1112          2 2013-01-01      0          0     0      0
# 1017206   1113          2 2013-01-01      0          0     0      0
# 1017207   1114          2 2013-01-01      0          0     0      0
# 1017208   1115          2 2013-01-01      0          0     0      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %% [markdown]
# **Store open/close**

# %%
merged_df[merged_df.Open==0].Sales
# Out:
# 291        0
# 875        0
# 1406       0
# 1990       0
# 2521       0
#           ..
# 1017204    0
# 1017205    0
# 1017206    0
# 1017207    0
# 1017208    0
# Name: Sales, Length: 172817, dtype: int64

# %%
merged_df[merged_df.Open==0].Sales.value_counts()
# Out:
# Sales
# 0    172817
# Name: count, dtype: int64

# %% [markdown]
# all the sales are aero when the srorw is closed so i willl be better to remove all the rows when the store is closed

# %%
merged_df=merged_df[merged_df.Open==1].copy()
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %% [markdown]
# **Competition**
#
# we are calculating number od=f munths the competitors are open using current date

# %%
def comp_monts(df):
    df['CompetitionOpen']=12*(df.Year-df.CompetitionOpenSinceYear) +(df.Month-df.CompetitionOpenSinceMonth)
    df['CompetitionOpen']=df.CompetitionOpen.map(lambda x:0 if x<0 else x).fillna(0)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
comp_monts(merged_df)
comp_monts(merged_test_df)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %% [markdown]
# **Adding pramotions**

# %%
def check_promo_month(row):
    month2str={1:'Jan',2:'Feb',3:'Mar',4:'Apr',5:'May',6:'Jun',7:'Jul',8:'Aug',9:'Sept',10:'Oct',11:'Nov',12:'Dec'}
    try:
        months=(row['PromoInterval'] or '').split(',')
        if row['Promo2Open'] and month2str[row['Month']] in months:
            return 1
        else:
            return 0
    except Exception:
        return 0
def promo_cols(df):
    df['Promo2Open']=12*(df.Year-df.Promo2SinceYear)+((df.WeekOfYear-df.Promo2SinceWeek)/4)*df['Promo2']
    df['Promo2Open']=df.Promo2Open.map(lambda x:0 if x<0 else x).fillna(0)*df['Promo2']
    df['IsPromo2Month']=df.apply(check_promo_month,axis=1)*df['Promo2']

# %%
promo_cols(merged_df)
promo_cols(merged_test_df)

# %%
merged_df
# Out:
#          Store  DayOfWeek       Date  Sales  Customers  Open  Promo  \
# 0            1          5 2015-07-31   5263        555     1      1
# 1            2          5 2015-07-31   6064        625     1      1
# 2            3          5 2015-07-31   8314        821     1      1
# 3            4          5 2015-07-31  13995       1498     1      1
# 4            5          5 2015-07-31   4822        559     1      1
# ...        ...        ...        ...    ...        ...   ...    ...
# 1016776    682          2 2013-01-01   3375        566     1      0
# 1016827    733          2 2013-01-01  10765       2377     1      0
# 1016863    769          2 2013-01-01   5035       1248     1      0
# 1017042    948          2 2013-01-01   4491       1039     1      0
# 1017190   1097          2 2013-01-01   5961       1405     1      0
#
#         StateHoliday  SchoolHoliday StoreType Assortment  CompetitionDistance  \
# ...

# %%
merged_df.iloc[168074]
# Out:
# Store                                        807
# DayOfWeek                                      6
# Date                         2015-01-31 00:00:00
# Sales                                      11018
# Customers                                   1033
# Open                                           1
# Promo                                          0
# StateHoliday                                   0
# SchoolHoliday                                  0
# StoreType                                      a
# Assortment                                     a
# CompetitionDistance                       3870.0
# CompetitionOpenSinceMonth                    4.0
# CompetitionOpenSinceYear                  2008.0
# Promo2                                         0
# Promo2SinceWeek                              NaN
# Promo2SinceYear                              NaN
# PromoInterval                                NaN
# Year                                        2015
# ...

# %% [markdown]
# **Diving target and input columns**

# %%
merged_df.columns
# Out:
# Index(['Store', 'DayOfWeek', 'Date', 'Sales', 'Customers', 'Open', 'Promo',
#        'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
#        'CompetitionDistance', 'CompetitionOpenSinceMonth',
#        'CompetitionOpenSinceYear', 'Promo2', 'Promo2SinceWeek',
#        'Promo2SinceYear', 'PromoInterval', 'Year', 'Month', 'Day',
#        'WeekOfYear', 'CompetitionOpen', 'Promo2Open', 'IsPromo2Month'],
#       dtype='object')

# %%
inputs_cols=['Store', 'DayOfWeek', 'Promo',
       'StateHoliday', 'SchoolHoliday', 'StoreType', 'Assortment',
       'CompetitionDistance', 'CompetitionOpen', 'Year', 'Month', 'Day', 'WeekOfYear', 'Promo2', 'Promo2Open', 'IsPromo2Month']
target_cols='Sales'

# %%
inputs=merged_df[inputs_cols].copy()
targets=merged_df[target_cols].copy()

# %%
inputs
# Out:
#          Store  DayOfWeek  Promo StateHoliday  SchoolHoliday StoreType  \
# 0            1          5      1            0              1         c
# 1            2          5      1            0              1         a
# 2            3          5      1            0              1         a
# 3            4          5      1            0              1         c
# 4            5          5      1            0              1         a
# ...        ...        ...    ...          ...            ...       ...
# 1016776    682          2      0            a              1         b
# 1016827    733          2      0            a              1         b
# 1016863    769          2      0            a              1         b
# 1017042    948          2      0            a              1         b
# 1017190   1097          2      0            a              1         b
#
#         Assortment  CompetitionDistance  CompetitionOpen  Year  Month  Day  \
# ...

# %%
targets
# Out:
# 0           5263
# 1           6064
# 2           8314
# 3          13995
# 4           4822
#            ...
# 1016776     3375
# 1016827    10765
# 1016863     5035
# 1017042     4491
# 1017190     5961
# Name: Sales, Length: 844392, dtype: int64

# %%
test_inputs=merged_test_df[inputs_cols]
test_inputs
# Out:
#        Store  DayOfWeek  Promo StateHoliday  SchoolHoliday StoreType  \
# 0          1          4      1            0              0         c
# 1          3          4      1            0              0         a
# 2          7          4      1            0              0         a
# 3          8          4      1            0              0         a
# 4          9          4      1            0              0         a
# ...      ...        ...    ...          ...            ...       ...
# 41083   1111          6      0            0              0         a
# 41084   1112          6      0            0              0         c
# 41085   1113          6      0            0              0         a
# 41086   1114          6      0            0              0         a
# 41087   1115          6      0            0              1         d
#
#       Assortment  CompetitionDistance  CompetitionOpen  Year  Month  Day  \
# ...

# %%
num_cols=['Store', 'Promo',
       'SchoolHoliday',
       'CompetitionDistance', 'CompetitionOpen', 'Year', 'Month', 'Day', 'WeekOfYear', 'Promo2', 'Promo2Open', 'IsPromo2Month']
cat_cols=['DayOfWeek', 'StateHoliday', 'StoreType', 'Assortment']

# %%
inputs[num_cols].isna().sum()
# Out:
# Store                     0
# Promo                     0
# SchoolHoliday             0
# CompetitionDistance    2186
# CompetitionOpen           0
# Year                      0
# Month                     0
# Day                       0
# WeekOfYear                0
# Promo2                    0
# Promo2Open                0
# IsPromo2Month             0
# dtype: int64

# %%
test_inputs[num_cols].isna().sum()
# Out:
# Store                   0
# Promo                   0
# SchoolHoliday           0
# CompetitionDistance    96
# CompetitionOpen         0
# Year                    0
# Month                   0
# Day                     0
# WeekOfYear              0
# Promo2                  0
# Promo2Open              0
# IsPromo2Month           0
# dtype: int64

# %%
max_distance=inputs.CompetitionDistance.max()
inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
test_inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17248\2640819914.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   inputs['CompetitionDistance'].fillna(max_distance*2,inplace=True)
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17248\2640819914.py:3: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
inputs[num_cols].isna().sum()
# Out:
# Store                  0
# Promo                  0
# SchoolHoliday          0
# CompetitionDistance    0
# CompetitionOpen        0
# Year                   0
# Month                  0
# Day                    0
# WeekOfYear             0
# Promo2                 0
# Promo2Open             0
# IsPromo2Month          0
# dtype: int64

# %%
test_inputs[num_cols].isna().sum()
# Out:
# Store                  0
# Promo                  0
# SchoolHoliday          0
# CompetitionDistance    0
# CompetitionOpen        0
# Year                   0
# Month                  0
# Day                    0
# WeekOfYear             0
# Promo2                 0
# Promo2Open             0
# IsPromo2Month          0
# dtype: int64

# %% [markdown]
# **scaling the data**

# %%
inputs[num_cols].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 844392 entries, 0 to 1017190
# Data columns (total 12 columns):
#  #   Column               Non-Null Count   Dtype
# ---  ------               --------------   -----
#  0   Store                844392 non-null  int64
#  1   Promo                844392 non-null  int64
#  2   SchoolHoliday        844392 non-null  int64
#  3   CompetitionDistance  844392 non-null  float64
#  4   CompetitionOpen      844392 non-null  float64
#  5   Year                 844392 non-null  int32
#  6   Month                844392 non-null  int32
#  7   Day                  844392 non-null  int32
#  8   WeekOfYear           844392 non-null  UInt32
#  9   Promo2               844392 non-null  int64
#  10  Promo2Open           844392 non-null  float64
#  11  IsPromo2Month        844392 non-null  int64
# dtypes: UInt32(1), float64(3), int32(3), int64(5)
# memory usage: 71.7 MB

# %%
from sklearn.preprocessing import MinMaxScaler,OneHotEncoder
scaler=MinMaxScaler().fit(inputs[num_cols])
encoder=OneHotEncoder(sparse_output=False,handle_unknown='ignore').fit(inputs[cat_cols])
encoded_cols=list(encoder.get_feature_names_out(cat_cols))

# %%
inputs[num_cols]=scaler.transform(inputs[num_cols])
test_inputs[num_cols]=scaler.transform(test_inputs[num_cols])
inputs[encoded_cols]=encoder.transform(inputs[cat_cols])
test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# Out:
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17248\3462026187.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[num_cols]=scaler.transform(test_inputs[num_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17248\3462026187.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test_inputs[encoded_cols]=encoder.transform(test_inputs[cat_cols])
# C:\Users\DELL\AppData\Local\Temp\ipykernel_17248\3462026187.py:4: SettingWithCopyWarning:
# ...

# %%
inputs.describe()
# Out:
#                Store      DayOfWeek          Promo  SchoolHoliday  \
# count  844392.000000  844392.000000  844392.000000  844392.000000
# mean        0.500380       3.520361       0.446352       0.193580
# std         0.288808       1.723689       0.497114       0.395103
# min         0.000000       1.000000       0.000000       0.000000
# 25%         0.250449       2.000000       0.000000       0.000000
# 50%         0.500000       3.000000       0.000000       0.000000
# 75%         0.750449       5.000000       1.000000       0.000000
# max         1.000000       7.000000       1.000000       1.000000
#
#        CompetitionDistance  CompetitionOpen           Year          Month  \
# count        844392.000000    844392.000000  844392.000000  844392.000000
# mean              0.038343         0.030270       0.415969       0.440522
# std               0.071018         0.047034       0.388630       0.302176
# min               0.000000         0.000000       0.000000       0.000000
# ...

# %% [markdown]
# ***Training a model***

# %%
X=inputs[num_cols+encoded_cols]
X_test=test_inputs[num_cols+encoded_cols]

# %%
from xgboost import XGBRegressor

# %%
model=XGBRegressor(random_state=41,n_jobs=-1,n_estimators=20,max_depth=4).fit(X,targets)

# %%
pred=model.predict(X)
pred
# Out:
# array([ 8161.051 ,  7379.584 ,  8871.791 , ...,  9311.399 ,  7845.6377,
#        10193.34  ], shape=(844392,), dtype=float32)

# %%
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score,root_mean_squared_error
def rmse(a,b):
    return root_mean_squared_error(a,b)
rmse(pred,targets)
# Out:
# 2404.82080078125

# %%
plt.hist(merged_df.Sales.sample(10000))
# Out:
# (array([5.350e+02, 4.539e+03, 3.421e+03, 1.051e+03, 3.020e+02, 8.700e+01,
#         4.300e+01, 1.400e+01, 6.000e+00, 2.000e+00]),
#  array([    0. ,  3214.9,  6429.8,  9644.7, 12859.6, 16074.5, 19289.4,
#         22504.3, 25719.2, 28934.1, 32149. ]),
#  <BarContainer object of 10 artists>)

# %%
importance_df=pd.DataFrame({
    'features':X.columns,
    'importance':model.feature_importances_
})
importance_df.sort_values('importance',ascending=False).head(10)
# Out:
#                features  importance
# 1                 Promo    0.252731
# 12          DayOfWeek_1    0.100153
# 9                Promo2    0.090695
# 26          StoreType_d    0.069385
# 24          StoreType_b    0.067187
# 27         Assortment_a    0.055935
# 8            WeekOfYear    0.043562
# 3   CompetitionDistance    0.041989
# 0                 Store    0.033509
# 6                 Month    0.032903

# %%
plt.figure(figsize=(10,6))
plt.title("importance graph")
sns.barplot(data=importance_df.sort_values('importance',ascending=False).head(10),x='importance',y='features')
# Out:
# <Axes: title={'center': 'importance graph'}, xlabel='importance', ylabel='features'>

# %% [markdown]
# ***K-FOLD Cross Validation***

# %%
def train_and_evaluate(X_train,train_targets,X_val,val_targets,**params):
    model=XGBRegressor(random_state=42,n_jobs=-1,**params).fit(X_train,train_targets)
    train_rmse=rmse(model.predict(X_train),train_targets)
    val_rmse=rmse(model.predict(X_val),val_targets)
    return model,train_rmse,val_rmse

# %%
from sklearn.model_selection import KFold
kFold=KFold(n_splits=5)
models=[]
for train_idxs,val_idxs in kFold.split(X):
    X_train,train_targets=X.iloc[train_idxs],targets.iloc[train_idxs]
    X_val,val_targets=X.iloc[val_idxs],targets.iloc[val_idxs]
    model,train_rmse,val_rmse=train_and_evaluate(X_train,train_targets,X_val,val_targets,max_depth=4,n_estimators=20)
    models.append(model)
    print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse,val_rmse))
# Out:
# Train RMSE: 2390.99560546875, Validation RMSE: 2461.603515625
# Train RMSE: 2383.4375, Validation RMSE: 2418.56298828125
# Train RMSE: 2366.869873046875, Validation RMSE: 2336.755126953125
# Train RMSE: 2389.548583984375, Validation RMSE: 2488.663330078125
# Train RMSE: 2374.4306640625, Validation RMSE: 2453.164794921875

# %%
def pred_avg(models,inputs):
    return np.mean([model.predict(inputs) for model in models],axis=0)

# %%
preds=pred_avg(models,X)
preds_vals=pred

# %%
rmse(preds,targets)
# Out:
# 2373.5625

# %% [markdown]
# ***Training again***

# %%
from sklearn.model_selection import train_test_split
X_train,X_val,train_targets,val_targets=train_test_split(X,targets,test_size=0.1)

# %%
# def test_params(**params):
#     model=XGBRegressor(n_jobs=-1,random_state=42,**params).fit(X_train,train_targets)
#     train_rmse=rmse(model.predict(X_train),train_targets)
#     val_rmse=rmse(model.predict(X_val),val_targets)
#     print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse,val_rmse))
#     print('Train Accuracy: {}, Validation Accuracy: {}'.format(accuracy_score(model.predict(X_train),train_targets),accuracy_score(model.predict(X_val),val_targets)))


def evaluate_regression(y_true, y_pred):
    rmse = np.sqrt(mean_squared_error(y_true, y_pred))
    mae = mean_absolute_error(y_true, y_pred)
    r2 = r2_score(y_true, y_pred)
    rmspe_val = np.sqrt(np.mean(np.square((y_true - y_pred) / y_true))) * 100

    print(f"RMSE: {rmse:.2f}")
    print(f"MAE: {mae:.2f}")
    print(f"R² Score: {r2:.4f}")
    print(f"RMSPE: {rmspe_val:.2f}%")

def test_params(**params):
    model = XGBRegressor(n_jobs=-1, random_state=42, **params)
    model.fit(X_train, train_targets)
    
    print("\n📊 Training Evaluation:")
    evaluate_regression(train_targets, model.predict(X_train))
    
    print("\n📊 Validation Evaluation:")
    evaluate_regression(val_targets, model.predict(X_val))

# %% [markdown]
# **n_estimaters**

# %%
test_params(n_estimators=10)
test_params(n_estimators=30)
test_params(n_estimators=100)
test_params(n_estimators=200)
test_params(n_estimators=240)
test_params(n_estimators=300)
# Out:
# 📊 Training Evaluation:
# RMSE: 2341.14
# MAE: 1729.81
# R² Score: 0.4302
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 2361.85
# MAE: 1741.00
# R² Score: 0.4298
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 1863.90
# MAE: 1370.77
# R² Score: 0.6389
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1878.41
# MAE: 1379.34
# R² Score: 0.6393
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 1179.10
# MAE: 842.40
# R² Score: 0.8555
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1193.29
# MAE: 849.94
# R² Score: 0.8544
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 939.73
# MAE: 660.38
# R² Score: 0.9082
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 957.72
# MAE: 670.31
# R² Score: 0.9062
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 903.29
# MAE: 633.79
# R² Score: 0.9152
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 924.15
# MAE: 645.09
# R² Score: 0.9127
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 861.63
# MAE: 604.29
# R² Score: 0.9228
# RMSPE: inf%
#
# ...

# %% [markdown]
# **max_depth**

# %%
test_params(n_estimators=100, max_depth=5)
test_params(n_estimators=100, max_depth=10)
test_params(n_estimators=100, max_depth=11)
test_params(n_estimators=100, max_depth=12)
test_params(n_estimators=100, max_depth=13)
test_params(n_estimators=100, max_depth=14)
# Out:
# 📊 Training Evaluation:
# RMSE: 1407.38
# MAE: 1020.39
# R² Score: 0.7941
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1419.38
# MAE: 1026.96
# R² Score: 0.7941
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 673.08
# MAE: 477.25
# R² Score: 0.9529
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 776.36
# MAE: 533.63
# R² Score: 0.9384
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 592.17
# MAE: 423.49
# R² Score: 0.9635
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 745.77
# MAE: 511.89
# R² Score: 0.9431
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 511.66
# MAE: 368.22
# R² Score: 0.9728
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 742.07
# MAE: 500.06
# R² Score: 0.9437
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 438.37
# MAE: 316.35
# R² Score: 0.9800
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 748.55
# MAE: 500.51
# R² Score: 0.9427
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 363.40
# MAE: 262.47
# R² Score: 0.9863
# RMSPE: inf%
#
# ...

# %% [markdown]
# **Learning rate**

# %%
test_params(n_estimators=100, learning_rate=0.1)
test_params(n_estimators=100, learning_rate=0.3)
test_params(n_estimators=100, learning_rate=0.4)
test_params(n_estimators=100, learning_rate=0.5)
test_params(n_estimators=100, learning_rate=0.6)
test_params(n_estimators=100, learning_rate=0.75)
test_params(n_estimators=100, learning_rate=0.99)
# Out:
# 📊 Training Evaluation:
# RMSE: 1856.56
# MAE: 1364.25
# R² Score: 0.6417
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1871.71
# MAE: 1372.87
# R² Score: 0.6419
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 1179.10
# MAE: 842.40
# R² Score: 0.8555
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1193.29
# MAE: 849.94
# R² Score: 0.8544
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 1067.07
# MAE: 755.96
# R² Score: 0.8816
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1085.92
# MAE: 764.59
# R² Score: 0.8795
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 1012.06
# MAE: 716.64
# R² Score: 0.8935
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1032.46
# MAE: 728.45
# R² Score: 0.8910
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 982.32
# MAE: 697.20
# R² Score: 0.8997
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 1000.65
# MAE: 707.94
# R² Score: 0.8976
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 940.58
# MAE: 669.25
# R² Score: 0.9080
# RMSPE: inf%
#
# ...

# %%
test_params(n_estimators=300, max_depth=13, learning_rate=0.6)
test_params(n_estimators=300, max_depth=12, learning_rate=0.7)
test_params(n_estimators=300, max_depth=12, learning_rate=0.6)
test_params(n_estimators=300, max_depth=11, learning_rate=0.5)
test_params(n_estimators=300, max_depth=10, learning_rate=0.4)
test_params(n_estimators=300, max_depth=10, learning_rate=0.45)
test_params(n_estimators=300, max_depth=9, learning_rate=0.45)
# Out:
# 📊 Training Evaluation:
# RMSE: 129.91
# MAE: 88.10
# R² Score: 0.9982
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 826.41
# MAE: 561.75
# R² Score: 0.9302
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 204.51
# MAE: 143.81
# R² Score: 0.9957
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 828.70
# MAE: 567.75
# R² Score: 0.9298
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 226.50
# MAE: 160.12
# R² Score: 0.9947
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 800.57
# MAE: 545.70
# R² Score: 0.9345
# RMSPE: inf%
#
# 📊 Training Evaluation:
# RMSE: 339.97
# MAE: 247.21
# R² Score: 0.9880
# RMSPE: inf%
#
# 📊 Validation Evaluation:
# RMSE: 733.79
# MAE: 499.33
# R² Score: 0.9450
# RMSPE: inf%

# %% [markdown]
# ***Booster***

# %%
test_params(booster='gblinear')
# Out:
# Train RMSE: 2725.8828125, Validation RMSE: 2741.117919921875
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 test_params(booster='gblinear')
#
# Cell In[99], line 6, in test_params(**params)
#       4 val_rmse=rmse(model.predict(X_val),val_targets)
#       5 print('Train RMSE: {}, Validation RMSE: {}'.format(train_rmse,val_rmse))
# ----> 6 print('Train Accuracy: {}, Validation Accuracy: {}'.format(accuracy_score(model.predict(X_train),train_targets),accuracy_score(model.predict(X_val),val_targets)))
#
# File d:\ai\.venv\Lib\site-packages\sklearn\utils\_param_validation.py:218, in validate_params.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     212 try:
#     213     with config_context(
#     214         skip_parameter_validation=(
#     215             prefer_skip_nested_validation or global_skip_validation
#     216         )
# ...

# %% [markdown]
# ***final code with various hyperparameters mixed***

# %%
test_params(n_estimators=300, max_depth=10, learning_rate=0.4, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=500, max_depth=10, learning_rate=0.4, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=300, max_depth=12, learning_rate=0.4, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=300, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=300, max_depth=10, learning_rate=0.4, subsample=0.8, colsample_bytree=0.7)
test_params(n_estimators=300, max_depth=10, learning_rate=0.4, subsample=0.9, colsample_bytree=0.6)
# Out:
# Train RMSE: 475.5830383300781, Validation RMSE: 712.4583129882812
# Train RMSE: 394.9876708984375, Validation RMSE: 705.0851440429688
# Train RMSE: 298.1230773925781, Validation RMSE: 730.2936401367188
# Train RMSE: 504.67327880859375, Validation RMSE: 699.8943481445312
# Train RMSE: 483.9056701660156, Validation RMSE: 714.1309814453125
# Train RMSE: 490.2196350097656, Validation RMSE: 713.88671875

# %%
test_params(n_estimators=1000, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7)
# Out:
# Train RMSE: 316.82598876953125, Validation RMSE: 680.6963500976562

# %%
test_params(n_estimators=600, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=700, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=800, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7)
test_params(n_estimators=900, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7)
# Out:
# Train RMSE: 395.7214660644531, Validation RMSE: 682.2710571289062
# Train RMSE: 372.13818359375, Validation RMSE: 681.3626708984375
# Train RMSE: 351.8116149902344, Validation RMSE: 680.8400268554688
# Train RMSE: 333.1068420410156, Validation RMSE: 680.5325927734375

# %% [markdown]
# ***the final hyperparameters are((n_estimators=900, max_depth=10, learning_rate=0.3, subsample=0.9, colsample_bytree=0.7))***

# %%
model=XGBRegressor(n_jobs=-1,random_state=42,n_estimators=1000, max_depth=10, learning_rate=0.2, subsample=0.9, colsample_bytree=0.7).fit(X,targets)

# %%
train_preds=model.predict(X)
rmse(train_preds,targets)
# Out:
# 379.38348388671875

# %%
test_preds=model.predict(X_test)
test_preds
# Out:
# array([ 4082.0334,  7509.7246,  9793.903 , ...,  6271.8745, 25064.55  ,
#         7558.849 ], shape=(41088,), dtype=float32)

# %% [markdown]
# **Saving testing predictions to submissions**

# %%
submissions_df=pd.read_csv('sample_submission.csv')
submissions_df
# Out:
#           Id  Sales
# 0          1      0
# 1          2      0
# 2          3      0
# 3          4      0
# 4          5      0
# ...      ...    ...
# 41083  41084      0
# 41084  41085      0
# 41085  41086      0
# 41086  41087      0
# 41087  41088      0
#
# [41088 rows x 2 columns]

# %%
submissions_df['Sales']=test_preds
submissions_df
# Out:
#           Id         Sales
# 0          1   4082.033447
# 1          2   7509.724609
# 2          3   9793.903320
# 3          4   7138.734863
# 4          5   7284.465332
# ...      ...           ...
# 41083  41084   2929.577881
# 41084  41085   7434.390625
# 41085  41086   6271.874512
# 41086  41087  25064.550781
# 41087  41088   7558.849121
#
# [41088 rows x 2 columns]

# %%
submissions_df.isna().sum()
# Out:
# Id       0
# Sales    0
# dtype: int64

# %%
submissions_df['Sales']=submissions_df['Sales']*test_df.Open.fillna(1.)

# %%
submissions_df.isna().sum(),submissions_df
# Out:
# (Id       0
#  Sales    0
#  dtype: int64,
#            Id         Sales
#  0          1   4082.033447
#  1          2   7509.724609
#  2          3   9793.903320
#  3          4   7138.734863
#  4          5   7284.465332
#  ...      ...           ...
#  41083  41084   2929.577881
#  41084  41085   7434.390625
#  41085  41086   6271.874512
#  41086  41087  25064.550781
#  41087  41088   7558.849121
#
#  [41088 rows x 2 columns])

# %%
submissions_df.sample(20)
# Out:
#           Id         Sales
# 2769    2770  20516.000000
# 24150  24151   6221.541016
# 29243  29244   5528.955566
# 11257  11258   5001.688965
# 8498    8499   5894.077637
# 40878  40879  22550.613281
# 11104  11105   4045.736816
# 31441  31442   8099.931641
# 4633    4634   9779.610352
# 35286  35287   7686.142578
# 16309  16310   3873.699707
# 30232  30233   6315.128418
# 13052  13053   9217.245117
# 38955  38956   7847.118164
# 3372    3373  10205.795898
# 28037  28038      0.000000
# 22370  22371   2656.590576
# 1667    1668   9280.457031
# 5075    5076   5011.837402
# 31487  31488   6124.552246

# %%
submissions_df.to_csv('submission3.csv',index=None)
